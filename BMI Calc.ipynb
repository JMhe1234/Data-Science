# %%
input_type = input("Enter 1 for metric or 2 for imperical measurements")

if input_type == "1":
    name = input("Enter your name: ")
    weight = float(input("Enter your weight in KG: "))
    height = float(input("Enter your height in metres: "))
    BMI = round(weight / (height**2),2)

    if BMI>0:
        if(BMI<18.5):
            print(name + ", your BMI is, " + str(BMI) + ", you are underweight.")
        elif (BMI<=22.9):
             print(name + ", your BMI is, " + str(BMI) + ", you are a healthy weight.")
        elif (BMI<=27.4):
             print(name + ", your BMI is, " + str(BMI) + ", you are overweight.")
        else:
             print(name + ", your BMI is, " + str(BMI) + ", you are obese.")
    else:
        print("Enter valid input")

elif input_type == "2":
    name = input("Enter your name: ")
    weight = float(input("Enter your weight in pounds: "))
    height = float(input("Enter your height in inches: "))
    BMI = round((weight * 703) / (height**2),2)

    if BMI>0:
        if(BMI<18.5):
            print(name + ", your BMI is, " + str(BMI) + ", you are underweight.")
        elif (BMI<=24.9):
             print(name + ", your BMI is, " + str(BMI) + ", you are a healthy weight.")
        elif (BMI<=29.9):
             print(name + ", your BMI is, " + str(BMI) + ", you are overweight.")
        elif (BMI<=34.9):
            print(name + ", your BMI is, " + str(BMI) + ", you are severely obese.")
        else:
             print(name + ", your BMI is, " + str(BMI) + ", you are morbidly obese.")
    else:
        print("Enter valid input")
else:
    print("Please enter a valid input")
# Out:
# Enter 1 for metric or 2 for imperical measurements 1
# Enter your name:  Jamal
# Enter your weight in KG:  116
# Enter your height in metres:  1.79
# Jamal, your BMI is, 36.2, you are obese.

# %%
def bmi():
    input_type = input("Enter 1 for metric or 2 for imperical measurements")
    
    if input_type == "1":
        name = input("Enter your name: ")
        weight = float(input("Enter your weight in KG: "))
        height = float(input("Enter your height in metres: "))
        BMI = round(weight / (height**2),2)
    
        if BMI>0:
            if(BMI<18.5):
                print(name + ", your BMI is, " + str(BMI) + ", you are underweight.")
            elif (BMI<=22.9):
                 print(name + ", your BMI is, " + str(BMI) + ", you are a healthy weight.")
            elif (BMI<=27.4):
                 print(name + ", your BMI is, " + str(BMI) + ", you are overweight.")
            else:
                 print(name + ", your BMI is, " + str(BMI) + ", you are obese.")
        else:
            print("Enter valid input")
    
    elif input_type == "2":
        name = input("Enter your name: ")
        weight = float(input("Enter your weight in pounds: "))
        height = float(input("Enter your height in inches: "))
        BMI = round((weight * 703) / (height**2),2)
    
        if BMI>0:
            if(BMI<18.5):
                print(name + ", your BMI is, " + str(BMI) + ", you are underweight.")
            elif (BMI<=24.9):
                 print(name + ", your BMI is, " + str(BMI) + ", you are a healthy weight.")
            elif (BMI<=29.9):
                 print(name + ", your BMI is, " + str(BMI) + ", you are overweight.")
            elif (BMI<=34.9):
                print(name + ", your BMI is, " + str(BMI) + ", you are severely obese.")
            else:
                 print(name + ", your BMI is, " + str(BMI) + ", you are morbidly obese.")
        else:
            print("Enter valid input")
    else:
        print("Please enter a valid input")

# %%
bmi()
# Out:
# Enter 1 for metric or 2 for imperical measurements 1
# Enter your name:  Jamal
# Enter your weight in KG:  116
# Enter your height in metres:  1.79
# Jamal, your BMI is, 36.2, you are obese.

# %%
bmi()
# Out:
# Enter 1 for metric or 2 for imperical measurements 2
# Enter your name:  Jamal
# Enter your weight in pounds:  257.77
# Enter your height in inches:  70.4
# Jamal, your BMI is, 36.56, you are morbidly obese.
